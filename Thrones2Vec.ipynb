# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /home/parth/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/parth/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = ['got1.txt','got2.txt','got3.txt','got4.txt','got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# [u'Heraldic', u'crest', u'by', u'Virginia', u'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2017-06-03 14:45:59,093 : INFO : collecting all words and their counts
# 2017-06-03 14:45:59,095 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-06-03 14:45:59,144 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2017-06-03 14:45:59,185 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2017-06-03 14:45:59,234 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2017-06-03 14:45:59,274 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2017-06-03 14:45:59,314 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2017-06-03 14:45:59,372 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2017-06-03 14:45:59,418 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2017-06-03 14:45:59,466 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2017-06-03 14:45:59,512 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2017-06-03 14:45:59,554 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2017-06-03 14:45:59,600 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2017-06-03 14:45:59,644 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2017-06-03 14:45:59,682 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2017-06-03 14:45:59,684 : INFO : Loading a fresh vocabulary
# 2017-06-03 14:45:59,746 : INFO : min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2017-06-03 14:45:59,747 : INFO : min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2017-06-03 14:45:59,809 : INFO : deleting the raw counts dictionary of 29026 items
# 2017-06-03 14:45:59,812 : INFO : sample=0.001 downsamples 50 most-common words
# 2017-06-03 14:45:59,817 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# 2017-06-03 14:45:59,820 : INFO : estimated required memory for 17277 words and 300 dimensions: 50103300 bytes
# 2017-06-03 14:45:59,896 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences, total_examples=token_count, epochs=5)
# Out:
# 2017-06-03 14:46:33,405 : INFO : training model with 4 workers on 17277 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-06-03 14:46:34,419 : INFO : PROGRESS: at 0.19% examples, 184720 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:35,471 : INFO : PROGRESS: at 0.39% examples, 187706 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:36,476 : INFO : PROGRESS: at 0.62% examples, 194199 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:37,506 : INFO : PROGRESS: at 0.81% examples, 194430 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:38,530 : INFO : PROGRESS: at 1.01% examples, 194699 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:39,543 : INFO : PROGRESS: at 1.22% examples, 195182 words/s, in_qsize 7, out_qsize 0
# 2017-06-03 14:46:40,545 : INFO : PROGRESS: at 1.41% examples, 195748 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:41,590 : INFO : PROGRESS: at 1.61% examples, 195276 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:42,630 : INFO : PROGRESS: at 1.83% examples, 195858 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:43,643 : INFO : PROGRESS: at 2.04% examples, 196095 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:44,663 : INFO : PROGRESS: at 2.24% examples, 196872 words/s, in_qsize 7, out_qsize 0
# 2017-06-03 14:46:45,676 : INFO : PROGRESS: at 2.45% examples, 196925 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:46,731 : INFO : PROGRESS: at 2.66% examples, 196933 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:47,734 : INFO : PROGRESS: at 2.85% examples, 197093 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:48,735 : INFO : PROGRESS: at 3.05% examples, 196822 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:49,794 : INFO : PROGRESS: at 3.26% examples, 196813 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:50,827 : INFO : PROGRESS: at 3.48% examples, 197096 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:51,835 : INFO : PROGRESS: at 3.68% examples, 197640 words/s, in_qsize 7, out_qsize 0
# 2017-06-03 14:46:52,839 : INFO : PROGRESS: at 3.88% examples, 197336 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:53,882 : INFO : PROGRESS: at 4.09% examples, 197419 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:54,940 : INFO : PROGRESS: at 4.29% examples, 197354 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:56,052 : INFO : PROGRESS: at 4.51% examples, 197201 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:57,105 : INFO : PROGRESS: at 4.73% examples, 197595 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:58,122 : INFO : PROGRESS: at 4.94% examples, 197587 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:46:59,173 : INFO : PROGRESS: at 5.13% examples, 197054 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:00,199 : INFO : PROGRESS: at 5.28% examples, 194956 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:01,206 : INFO : PROGRESS: at 5.45% examples, 193710 words/s, in_qsize 7, out_qsize 0
# 2017-06-03 14:47:02,236 : INFO : PROGRESS: at 5.61% examples, 192651 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:03,244 : INFO : PROGRESS: at 5.78% examples, 191822 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:04,291 : INFO : PROGRESS: at 5.95% examples, 190820 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:05,328 : INFO : PROGRESS: at 6.13% examples, 189959 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:06,366 : INFO : PROGRESS: at 6.31% examples, 189359 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:07,375 : INFO : PROGRESS: at 6.49% examples, 188968 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:08,392 : INFO : PROGRESS: at 6.65% examples, 188106 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:09,410 : INFO : PROGRESS: at 6.83% examples, 187500 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:10,455 : INFO : PROGRESS: at 6.96% examples, 185944 words/s, in_qsize 8, out_qsize 0
# 2017-06-03 14:47:11,256 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-06-03 14:47:11,328 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-06-03 14:47:11,343 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-06-03 14:47:11,370 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-06-03 14:47:11,371 : INFO : training on 9090515 raw words (7021120 effective words) took 38.0s, 184986 effective words/s
# 2017-06-03 14:47:11,373 : WARNING : supplied example count (644340) did not equal expected count (9090515)
# 7021120

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2017-06-03 14:47:30,778 : INFO : saving Word2Vec object under trained/thrones2vec.w2v, separately None
# 2017-06-03 14:47:30,781 : INFO : not storing attribute syn0norm
# 2017-06-03 14:47:30,783 : INFO : not storing attribute cum_table
# 2017-06-03 14:47:31,105 : INFO : saved trained/thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2017-06-03 14:47:53,166 : INFO : loading Word2Vec object from trained/thrones2vec.w2v
# 2017-06-03 14:47:53,346 : INFO : loading wv recursively from trained/thrones2vec.w2v.wv.* with mmap=None
# 2017-06-03 14:47:53,347 : INFO : setting ignored attribute syn0norm to None
# 2017-06-03 14:47:53,348 : INFO : setting ignored attribute cum_table to None
# 2017-06-03 14:47:53,349 : INFO : loaded trained/thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#         word         x         y
# 0       fawn -2.296788 -1.585880
# 1    raining -0.205986 -2.815630
# 2   writings -3.539322 -2.619409
# 3     Ysilla -3.327458 -2.836817
# 4       Rory -3.504961 -3.064005
# 5     hordes -3.295710 -3.850800
# 6  mustachio  2.513042 -2.140707
# 7    Greyjoy  0.764825  1.152354
# 8     yellow  3.504269 -2.120933
# 9       four -4.494155 -2.398458

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-784443c41ea3> in <module>()
# ----> 1 plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))
#
# <ipython-input-54-a0b27d5b6d50> in plot_region(x_bounds, y_bounds)
#       7     ]
#       8
# ----> 9     ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
#      10     slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
#      11     for i, point in slice.iterrows():
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in scatter(self, x, y, s, c, **kwds)
#    3950         axes : matplotlib.AxesSubplot or np.array of them
#    3951         """
# -> 3952         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3953
#    3954     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in generate(self)
#    1039     def generate(self):
#    1040         self._args_adjust()
# -> 1041         self._compute_plot_data()
#    1042         self._setup_subplots()
#    1043         self._make_plot()
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1148         if is_empty:
#    1149             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1150                             'plot'.format(numeric_data.__class__.__name__))
#    1151
#    1152         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-9cdb9dc1fff1> in <module>()
# ----> 1 plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))
#
# <ipython-input-43-364f3a90a271> in plot_region(x_bounds, y_bounds)
#       7     ]
#       8
# ----> 9     ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
#      10     for i, point in slice.iterrows():
#      11         ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in scatter(self, x, y, s, c, **kwds)
#    3950         axes : matplotlib.AxesSubplot or np.array of them
#    3951         """
# -> 3952         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3953
#    3954     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in generate(self)
#    1039     def generate(self):
#    1040         self._args_adjust()
# -> 1041         self._compute_plot_data()
#    1042         self._setup_subplots()
#    1043         self._make_plot()
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _compute_plot_data(self)
#    1148         if is_empty:
#    1149             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1150                             'plot'.format(numeric_data.__class__.__name__))
#    1151
#    1152         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.most_similar("Stark")
# Out:
# 2017-06-03 15:41:19,736 : INFO : precomputing L2-norms of word weight vectors
# [(u'Eddard', 0.590928852558136),
#  (u'Knelt', 0.5552698373794556),
#  (u'executed', 0.5400745272636414),
#  (u'Snowbeard', 0.537033200263977),
#  (u'Karstark', 0.5199676752090454),
#  (u'Edrick', 0.5142302513122559),
#  (u'divulge', 0.5104952454566956),
#  (u'Arnolf', 0.509480893611908),
#  (u'plotted', 0.5065724849700928),
#  (u'Howland', 0.5024114847183228)]

# %%
thrones2vec.most_similar("Aerys")
# Out:
# [(u'Jaehaerys', 0.6748738288879395),
#  (u'II', 0.6369384527206421),
#  (u'Unlikely', 0.626984715461731),
#  (u'Conciliator', 0.6183205842971802),
#  (u'Defiance', 0.6066148281097412),
#  (u'Fifth', 0.6025187969207764),
#  (u'Maekar', 0.6011451482772827),
#  (u'Mad', 0.5916372537612915),
#  (u'Beggar', 0.5907194018363953),
#  (u'Torgon', 0.5879067778587341)]

# %%
thrones2vec.most_similar("direwolf")
# Out:
# [(u'muzzle', 0.5887595415115356),
#  (u'wolf', 0.5852667093276978),
#  (u'Ghost', 0.5199209451675415),
#  (u'unafraid', 0.5079432725906372),
#  (u'Asleep', 0.5054143667221069),
#  (u'Shaggydog', 0.4974977970123291),
#  (u'snarling', 0.49404165148735046),
#  (u'pup', 0.48965024948120117),
#  (u'wolfhounds', 0.4883385896682739),
#  (u'SHAGGYDOG', 0.4850841760635376)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "wine")
nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as Tyrion is related to wine
# Arya is related to Nymeria, as Dany is related to dragons
# u'Dany'
